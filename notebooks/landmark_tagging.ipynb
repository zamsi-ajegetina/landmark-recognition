# %%
# %%javascript
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }setInterval(ClickConnect,60000)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/zamsi-ajegetina/landmark-recognition.git
# !pip install -r requirements.txt

# %%
! pip install gdown -q
! gdown 10hLpehomjhFJTNbJkCRyc4lkV4Iaouan --output landmark_images.zip

# !unzip landmark_images.zip -d landmark-recognition/landmark_images
# !rm landmark_images.zip

# %%
# %cd landmark-recognition
# Out:
# /content/landmark-recognition

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  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
# wandb: WARNING Invalid choice
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jajegetina (jajegetina-wolim) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
import torch
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NO GPU')
# Out:
# Tesla T4

# %%
# !python ablation_runner.py --config configs/A0_scratch.yaml
# Out:
# ============================================================
#   Run: A0_scratch
# ============================================================
#
# Computing mean: 100%|██████████████████████| 6246/6246 [00:49<00:00, 125.11it/s]
# Computing std: 100%|███████████████████████| 6246/6246 [01:00<00:00, 103.79it/s]
# Dataset mean: tensor([0.4638, 0.4725, 0.4687]), std: tensor([0.2697, 0.2706, 0.3017])
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: jajegetina (jajegetina-wolim) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run r3qcy0hl (0.1s)
# wandb: ⣽ setting up run r3qcy0hl (0.1s)
# wandb: ⣾ setting up run r3qcy0hl (0.1s)
# wandb: ⣷ setting up run r3qcy0hl (0.1s)
# wandb: ⣯ setting up run r3qcy0hl (0.1s)
# wandb: ⣟ setting up run r3qcy0hl (0.6s)
# wandb: ⡿ setting up run r3qcy0hl (0.6s)
# wandb: ⢿ setting up run r3qcy0hl (0.6s)
# wandb: ⣻ setting up run r3qcy0hl (0.6s)
# wandb: ⣽ setting up run r3qcy0hl (0.6s)
# wandb: ⣾ setting up run r3qcy0hl (1.1s)
# wandb: ⣷ setting up run r3qcy0hl (1.1s)
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in /content/landmark-recognition/wandb/run-20260428_113807-r3qcy0hl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run A0_scratch
# wandb: ⭐️ View project at https://wandb.ai/jajegetina-wolim/african-landmark-recognition
# wandb: 🚀 View run at https://wandb.ai/jajegetina-wolim/african-landmark-recognition/runs/r3qcy0hl
# Training: 100%|███████████████████████████████| 125/125 [01:07<00:00,  1.86it/s]
# Validating: 100%|███████████████████████████████| 32/32 [00:08<00:00,  3.63it/s]
# Epoch   1 | Train Loss: 3.8770 | Val Loss: 3.7542 | LR: 1.00e-02
#   => Validation loss improved (3.7542). Saving checkpoint.
# Training: 100%|███████████████████████████████| 125/125 [01:06<00:00,  1.87it/s]
# Validating: 100%|███████████████████████████████| 32/32 [00:07<00:00,  4.55it/s]
# Epoch   2 | Train Loss: 3.7278 | Val Loss: 3.6816 | LR: 9.99e-03
#   => Validation loss improved (3.6816). Saving checkpoint.
# Training: 100%|███████████████████████████████| 125/125 [01:07<00:00,  1.86it/s]
# Validating: 100%|███████████████████████████████| 32/32 [00:09<00:00,  3.47it/s]
# Epoch   3 | Train Loss: 3.6543 | Val Loss: 3.5183 | LR: 9.96e-03
#   => Validation loss improved (3.5183). Saving checkpoint.
# Training: 100%|███████████████████████████████| 125/125 [01:06<00:00,  1.87it/s]
# Validating: 100%|███████████████████████████████| 32/32 [00:09<00:00,  3.33it/s]
# Epoch   4 | Train Loss: 3.5915 | Val Loss: 3.6326 | LR: 9.91e-03
# Training:  57%|██████████████████▏             | 71/125 [00:38<00:26,  2.06it/s]

# %%
# !python ablation_runner.py --config configs/A4_resnet50_full.yaml

# %%
# !python ablation_runner.py --config configs/A7_resnet50_minimal_aug.yaml

# %%
# !python ablation_runner.py --config configs/A8_resnet50_weighted.yaml

# %%
# !python ablation_runner.py --config configs/A6_vitb16_frozen.yaml
